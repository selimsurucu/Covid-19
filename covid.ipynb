# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from keras.preprocessing import image
import numpy as np
import pandas as pd
import os

# %%
class myCallback(tf.keras.callbacks.Callback): 
    def on_epoch_end(self, epoch, logs={}): 
        if(logs.get('accuracy') > 0.98):   
            print("\nReached %2.2f%% accuracy, so stopping training!!" %(0.98*100))   
            self.model.stop_training = True
callback= myCallback()

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
    directory = "data//train//",
    target_size=(150, 150),
    batch_size=8,
    class_mode="categorical")


validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_directory(
    directory = 'data//test//',
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical')
# Out:
# Found 5503 images belonging to 4 classes.
# Found 600 images belonging to 4 classes.

# %%
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 300x300 with 3 bytes color
    # This is the first convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fifth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),

    tf.keras.layers.Dense(4, activation='sigmoid')
])

# %%
model.compile(loss='mean_squared_error',
              optimizer=RMSprop(lr=0.001),
              metrics=['accuracy'])

# %%
model.fit_generator(
    train_generator,
    steps_per_epoch=100,
    epochs=100,
    validation_data=validation_generator,
    validation_steps=100,
    callbacks=[callback])
# Out:
# Epoch 1/100
# 100/100 [==============================] - 86s 859ms/step - loss: 0.1687 - accuracy: 0.4812 - val_loss: 0.1809 - val_accuracy: 0.3383
# Epoch 2/100
# 100/100 [==============================] - 79s 794ms/step - loss: 0.1572 - accuracy: 0.5263 - val_loss: 0.1803 - val_accuracy: 0.3816
# Epoch 3/100
# 100/100 [==============================] - 92s 919ms/step - loss: 0.1226 - accuracy: 0.6400 - val_loss: 0.1599 - val_accuracy: 0.4690
# Epoch 4/100
# 100/100 [==============================] - 91s 912ms/step - loss: 0.1221 - accuracy: 0.6308 - val_loss: 0.1191 - val_accuracy: 0.6823
# Epoch 5/100
# 100/100 [==============================] - 86s 859ms/step - loss: 0.1120 - accuracy: 0.6775 - val_loss: 0.0921 - val_accuracy: 0.7604
# Epoch 6/100
# 100/100 [==============================] - 81s 809ms/step - loss: 0.1066 - accuracy: 0.7138 - val_loss: 0.1513 - val_accuracy: 0.5152
# Epoch 7/100
# 100/100 [==============================] - 80s 800ms/step - loss: 0.0935 - accuracy: 0.7250 - val_loss: 0.0968 - val_accuracy: 0.7424
# Epoch 8/100
# 100/100 [==============================] - 76s 759ms/step - loss: 0.0936 - accuracy: 0.7337 - val_loss: 0.1437 - val_accuracy: 0.5430
# Epoch 9/100
# 100/100 [==============================] - 77s 770ms/step - loss: 0.0842 - accuracy: 0.7688 - val_loss: 0.1428 - val_accuracy: 0.6006
# Epoch 10/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.0894 - accuracy: 0.7400 - val_loss: 0.1435 - val_accuracy: 0.6146
# Epoch 11/100
# 100/100 [==============================] - 83s 833ms/step - loss: 0.0802 - accuracy: 0.7812 - val_loss: 0.1244 - val_accuracy: 0.6642
# Epoch 12/100
# 100/100 [==============================] - 88s 881ms/step - loss: 0.0870 - accuracy: 0.7513 - val_loss: 0.1034 - val_accuracy: 0.7294
# Epoch 13/100
# 100/100 [==============================] - 86s 861ms/step - loss: 0.0841 - accuracy: 0.7584 - val_loss: 0.1715 - val_accuracy: 0.5294
# Epoch 14/100
# 100/100 [==============================] - 89s 888ms/step - loss: 0.0847 - accuracy: 0.7625 - val_loss: 0.0949 - val_accuracy: 0.7345
# Epoch 15/100
# Epoch 96/100
# 100/100 [==============================] - 77s 768ms/step - loss: 0.0542 - accuracy: 0.8700 - val_loss: 0.1303 - val_accuracy: 0.6848
# Epoch 97/100
# 100/100 [==============================] - 78s 785ms/step - loss: 0.0465 - accuracy: 0.8863 - val_loss: 0.1162 - val_accuracy: 0.7272
# Epoch 98/100
# 100/100 [==============================] - 78s 776ms/step - loss: 0.0451 - accuracy: 0.8838 - val_loss: 0.1466 - val_accuracy: 0.6699
# Epoch 99/100
# 100/100 [==============================] - 76s 765ms/step - loss: 0.0441 - accuracy: 0.8875 - val_loss: 0.1443 - val_accuracy: 0.6544
# Epoch 100/100
# 100/100 [==============================] - 78s 779ms/step - loss: 0.0433 - accuracy: 0.8938 - val_loss: 0.0978 - val_accuracy: 0.7766

# %%
evaluate=model.evaluate_generator(generator=validation_generator,steps=300)
evaluate
# Out:
# [0.09694285653531551, 0.7783755]

# %%
def find_class(result_list):
    if result_list[0] == 1 :
        return "Bacteria"
    elif result_list[1] == 1 : 
        return "Covid"
    elif result_list[2] == 1 : 
        return "Normal"
    elif result_list[3] == 1 : 
        return "Virus"
    else:
        return "Sınıf Tespit edilemedi"

# %%
basepath = 'data//predict//'
for entry in os.listdir(basepath):
    if os.path.isfile(os.path.join(basepath, entry)):
        print(entry)
        img = image.load_img(os.path.join(basepath, entry), target_size=(150, 150))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)

        images = np.vstack([x])
        classes = model.predict(images, batch_size=10)
        print("Tahmin = " + find_class(classes[0]))
        print("XXXXXXXXXXXXXXXXXXXXXXXXXXX")
# Out:
# COVID-19 (1).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (10).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (100).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (104).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (11).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (12).png
# Tahmin = Virus
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (13).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (14).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (15).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (16).png
# Tahmin = Sınıf Tespit edilemedi
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (17).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (18).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (19).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (2).png
# Tahmin = Normal
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (20).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (21).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (22).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (23).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (24).png
# Tahmin = Bacteria
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (3).png
# Tahmin = Sınıf Tespit edilemedi
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (4).png
# Tahmin = Sınıf Tespit edilemedi
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (5).png
# Tahmin = Sınıf Tespit edilemedi
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (6).png
# Tahmin = Virus
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (7).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (8).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# COVID-19 (9).png
# Tahmin = Covid
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# NORMAL (1).png
# Tahmin = Normal
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# NORMAL (100).png
# Tahmin = Normal
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# NORMAL (1006).png
# Tahmin = Normal
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# NORMAL (1009).png
# Tahmin = Normal
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# NORMAL (1013).png
# Tahmin = Normal
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# Viral Pneumonia (10).png
# Tahmin = Virus
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# Viral Pneumonia (1001).png
# Tahmin = Virus
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# Viral Pneumonia (1006).png
# Tahmin = Virus
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# Viral Pneumonia (1008).png
# Tahmin = Virus
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
# Viral Pneumonia (1020).png
# Tahmin = Virus
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
